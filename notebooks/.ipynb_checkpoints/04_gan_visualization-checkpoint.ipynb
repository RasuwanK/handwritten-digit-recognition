# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import os

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(100, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 784),
            nn.Tanh()
        )

    def forward(self, x):
        return self.model(x)

# %%
generator = Generator()

generator.load_state_dict(torch.load("./generator.pth"))  # adjust if needed
generator.eval()

print("Generator loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 generator = Generator()
#       2
# ----> 3 generator.load_state_dict(torch.load("./generator.pth"))  # adjust if needed
#       4 generator.eval()
#       5
#       6 print("Generator loaded successfully!")
#
# File ~/Documents/handwritten-digit-recognition/.venv/lib64/python3.14/site-packages/torch/serialization.py:1530, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1527 if "encoding" not in pickle_load_args:
#    1528     pickle_load_args["encoding"] = "utf-8"
# -> 1530 with _open_file_like(f, "rb") as opened_file:
#    1531     if _is_zipfile(opened_file):
#    1532         # The zipfile reader is going to advance the current file position.
#    1533         # If we want to actually tail call to torch.jit.load, we need to
#    1534         # reset back to the original position.
#    1535         orig_position = opened_file.tell()
#
# File ~/Documents/handwritten-digit-recognition/.venv/lib64/python3.14/site-packages/torch/serialization.py:795, in _open_file_like(name_or_buffer, mode)
#     793 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     794     if _is_path(name_or_buffer):
# --> 795         return _open_file(name_or_buffer, mode)
#     796     else:
#     797         if "w" in mode:
#
# File ~/Documents/handwritten-digit-recognition/.venv/lib64/python3.14/site-packages/torch/serialization.py:776, in _open_file.__init__(self, name, mode)
#     775 def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 776     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './generator.pth'

# %%
noise = torch.randn(16, 100)   # 16 random inputs
generated_images = generator(noise).detach().numpy()

# %%
plt.figure(figsize=(6,6))

for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(generated_images[i].reshape(28,28), cmap='gray')
    plt.axis('off')

plt.suptitle("Generated Handwritten Digits")
plt.show()

# %%
output_dir = "../experiments/gan_samples"
os.makedirs(output_dir, exist_ok=True)

for i in range(16):
    plt.imsave(f"{output_dir}/digit_{i}.png",
               generated_images[i].reshape(28,28),
               cmap='gray')

print("Images saved successfully!")

# %%
noise = torch.randn(25, 100)
generated_images = generator(noise).detach().numpy()

plt.figure(figsize=(8,8))

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(generated_images[i].reshape(28,28), cmap='gray')
    plt.axis('off')

plt.show()
